# %% [markdown]
# ## <font color=purple> **NBL DATA FROM 2016/2017**
# ##### **Eric Nesi**
# ##### All Code in Python 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.linear_model import LinearRegression, LogisticRegressionCV, LogisticRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.model_selection import GridSearchCV, cross_val_score


plt.style.use('fivethirtyeight')

from ipywidgets import *
from IPython.display import display

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Part 1:
# #### Discussion:
# I figured I could use the counting stats for the year to set some X's, may come in handy after Part 3 as I really dive into the capstone, but wanted it in a csv, loaded into a notebook, and cleaned/grouped by team for the season.  I calculated effective field goal percentage which will be a good statistics to compare teams effective field goal percentage vs. Sydney's, compared to the rest of the year.

# %%
#Load in different dataset. Counting stats for the year.
nbl_totals = pd.read_csv('/Users/ericnesi/Desktop/capstone_eric/datasets/NBL_Player_Data.csv')

# %%
nbl_totals.head()
# Out:
#           Player                  Team  Games     Min  PTS  FGM  FGA   FG%  \
# 0     Adam Doyle        Adelaide 36ers     21  134.90   44   15   38  39.5
# 1    Adam Gibson      Brisbane Bullets     21  613.76  206   70  153  45.8
# 2  Akil Mitchell  New Zealand Breakers     25  568.47  238  105  189  55.6
# 3    Aleks Maric          Sydney Kings     28  496.75  150   60  101  59.4
# 4  Alex Loughton        Cairns Taipans     26  455.83  172   66  145  45.5
#
#    2PM  2PA ...   FTA   FT%  OR   DR   TR  AS  TO  ST  BL  PFS
# 0   11   22 ...    13  76.9   2    9   11  17  12   4   0   12
# 1   37   73 ...    35  94.3  11   43   54  79  33  21   4   60
# 2  103  186 ...    79  32.9  49  130  179  53  48  22  11   66
# 3   60  101 ...    58  51.7  56   75  131  34  46  32  19   90
# 4   41   84 ...    21  71.4  23   54   77  32  17  11   3   49
#
# [5 rows x 25 columns]

# %%
#Make new Dataframe that is just team totals
totals_team = nbl_totals.copy()

# %%
totals_team.head()
# Out:
#           Player                  Team  Games     Min  PTS  FGM  FGA   FG%  \
# 0     Adam Doyle        Adelaide 36ers     21  134.90   44   15   38  39.5
# 1    Adam Gibson      Brisbane Bullets     21  613.76  206   70  153  45.8
# 2  Akil Mitchell  New Zealand Breakers     25  568.47  238  105  189  55.6
# 3    Aleks Maric          Sydney Kings     28  496.75  150   60  101  59.4
# 4  Alex Loughton        Cairns Taipans     26  455.83  172   66  145  45.5
#
#    2PM  2PA ...   FTA   FT%  OR   DR   TR  AS  TO  ST  BL  PFS
# 0   11   22 ...    13  76.9   2    9   11  17  12   4   0   12
# 1   37   73 ...    35  94.3  11   43   54  79  33  21   4   60
# 2  103  186 ...    79  32.9  49  130  179  53  48  22  11   66
# 3   60  101 ...    58  51.7  56   75  131  34  46  32  19   90
# 4   41   84 ...    21  71.4  23   54   77  32  17  11   3   49
#
# [5 rows x 25 columns]

# %%
totals_team = totals_team.drop('Player', axis=1)

# %%
totals_team.head(1)
# Out:
#              Team  Games    Min  PTS  FGM  FGA   FG%  2PM  2PA   2P% ...   \
# 0  Adelaide 36ers     21  134.9   44   15   38  39.5   11   22  50.0 ...
#
#    FTA   FT%  OR  DR  TR  AS  TO  ST  BL  PFS
# 0   13  76.9   2   9  11  17  12   4   0   12
#
# [1 rows x 24 columns]

# %%
totals_team.columns
# Out:
# Index(['Team', 'Games', 'Min', 'PTS', 'FGM', 'FGA', 'FG%', '2PM', '2PA', '2P%',
#        '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OR', 'DR', 'TR', 'AS', 'TO',
#        'ST', 'BL', 'PFS'],
#       dtype='object')

# %%
totals_team = totals_team.groupby('Team').agg({'Games': np.max,'Min': np.sum,'PTS': np.sum, 'FGM': np.sum, 
                                                 'FG%': np.mean,'FGA': np.sum, '2PM': np.sum, '2PA': np.sum,
                                                  '2P%': np.mean,'3PM': np.sum, '3PA': np.sum,'3P%': np.mean,
                                                 'FTM': np.sum, 'FTA': np.sum, 'FT%': np.mean, 'OR': np.sum, 
                                                 'DR': np.sum, 'TR': np.sum, 'AS': np.sum, 'TO': np.sum,
                                                  'ST': np.sum, 'BL': np.sum, 'PFS': np.sum})

# %%
totals_team.head(8)
# Out:
#                       Games      Min   PTS   FGM        FG%   FGA  2PM   2PA  \
# Team
# Adelaide 36ers           31  6250.05  2867  1003  40.446154  2154  785  1540
# Brisbane Bullets         28  5649.68  2268   814  35.681250  1768  640  1279
# Cairns Taipans           30  6034.22  2440   847  34.420000  1955  574  1195
# Illawarra Hawks          34  6825.15  3010  1053  43.407692  2353  742  1472
# Melbourne United         28  5610.32  2345   851  40.575000  1941  585  1173
# New Zealand Breakers     28  5642.27  2353   852  40.152941  1859  597  1187
# Perth Wildcats           33  6699.64  2732   977  39.952941  2223  739  1515
# Sydney Kings             28  5599.99  2295   808  37.423529  1856  577  1159
#
#                             2P%  3PM ...   FTA        FT%   OR   DR    TR  \
# Team                                 ...
# Adelaide 36ers        42.646154  218 ...   863  60.876923  363  827  1190
# Brisbane Bullets      39.025000  174 ...   579  66.906250  294  638   932
# Cairns Taipans        37.740000  273 ...   603  63.180000  281  651   932
# Illawarra Hawks       44.800000  311 ...   779  76.207692  344  773  1117
# Melbourne United      44.112500  266 ...   528  60.018750  276  673   949
# New Zealand Breakers  42.435294  255 ...   572  65.017647  304  757  1061
# Perth Wildcats        42.894118  238 ...   739  53.894118  392  772  1164
# Sydney Kings          41.611765  231 ...   579  58.135294  272  628   900
#
#                        AS   TO   ST   BL  PFS
# Team
# Adelaide 36ers        535  442  174   86  645
# Brisbane Bullets      423  430  145   81  650
# Cairns Taipans        513  368  190   61  621
# Illawarra Hawks       667  453  287  119  724
# Melbourne United      422  288  168   78  553
# New Zealand Breakers  499  445  161   92  642
# Perth Wildcats        550  427  225  104  697
# Sydney Kings          473  323  214  111  598
#
# [8 rows x 23 columns]

# %%
#Effective Field Goal Percentage which includes 3pt being more than 2pt
totals_team['EFG%'] = (totals_team['FGM'] + (.5 * totals_team['3PM'])) / totals_team['FGA']

# %%
totals_team.head(8)
# Out:
#                       Games      Min   PTS   FGM        FG%   FGA  2PM   2PA  \
# Team
# Adelaide 36ers           31  6250.05  2867  1003  40.446154  2154  785  1540
# Brisbane Bullets         28  5649.68  2268   814  35.681250  1768  640  1279
# Cairns Taipans           30  6034.22  2440   847  34.420000  1955  574  1195
# Illawarra Hawks          34  6825.15  3010  1053  43.407692  2353  742  1472
# Melbourne United         28  5610.32  2345   851  40.575000  1941  585  1173
# New Zealand Breakers     28  5642.27  2353   852  40.152941  1859  597  1187
# Perth Wildcats           33  6699.64  2732   977  39.952941  2223  739  1515
# Sydney Kings             28  5599.99  2295   808  37.423529  1856  577  1159
#
#                             2P%  3PM    ...           FT%   OR   DR    TR  \
# Team                                    ...
# Adelaide 36ers        42.646154  218    ...     60.876923  363  827  1190
# Brisbane Bullets      39.025000  174    ...     66.906250  294  638   932
# Cairns Taipans        37.740000  273    ...     63.180000  281  651   932
# Illawarra Hawks       44.800000  311    ...     76.207692  344  773  1117
# Melbourne United      44.112500  266    ...     60.018750  276  673   949
# New Zealand Breakers  42.435294  255    ...     65.017647  304  757  1061
# Perth Wildcats        42.894118  238    ...     53.894118  392  772  1164
# Sydney Kings          41.611765  231    ...     58.135294  272  628   900
#
#                        AS   TO   ST   BL  PFS      EFG%
# Team
# Adelaide 36ers        535  442  174   86  645  0.516249
# Brisbane Bullets      423  430  145   81  650  0.509615
# Cairns Taipans        513  368  190   61  621  0.503069
# Illawarra Hawks       667  453  287  119  724  0.513600
# Melbourne United      422  288  168   78  553  0.506955
# New Zealand Breakers  499  445  161   92  642  0.526896
# Perth Wildcats        550  427  225  104  697  0.493027
# Sydney Kings          473  323  214  111  598  0.497575
#
# [8 rows x 24 columns]

# %%
total = totals_team['EFG%'].mean()
print(total)
# Out:
# 0.5083733959521314

# %%
Percentages = totals_team[['FG%', '2P%', '3P%', 'FT%', 'EFG%']]
Percentages.plot.bar(figsize=(13, 6))

# %%
Counting_Stats = totals_team[['FGM', 'FGA', '2PM', '2PA', '3PM', '3PA', 'PTS']]
plt.rc('xtick', labelsize=16) 
plt.rc('ytick', labelsize=16)
mycolors = 'rgbkymc' 
Counting_Stats.plot.bar(figsize=(20, 10), color = mycolors)

# %% [markdown]
# I wanted to create effective field goal percentage per team for the entire season.  Therefore, I could see if teams shot better or worse agains the Kings using this number.   I am debating potentially using as a threshhold for a classification regression based on this variable.  However, I can't really figure out how I want to tackle that yet.  That said, it seems like this data is good to have going forward so I went through and downloaded.  These basic stats allow me to calculate what are known as "Advanced Statistics" for the entire league.

# %% [markdown]
# ### Part 2:
# #### Discussion:
# I am going to load my dataframe from Pt. 2 of capstone, which I exported to csv at the end of Pt. 2.  This is the dataframe with all my defensive shot data for the Kings. I will then set some 'X's', standardize them, look for correlation, run a regression model with result as my target.

# %%
#read in CSV, maintain index, right now the data is sorted by distance. 
kings = pd.read_csv('/Users/ericnesi/Desktop/capstone_eric/datasets/kings_df.csv', index_col=[0])

# %%
kings.head()
# Out:
#                       Team  teamScore      opponent  opponentScore  \
# 633         Perth Wildcats         93  Sydney Kings             80
# 1743        Perth Wildcats        101  Sydney Kings             74
# 1774        Perth Wildcats        101  Sydney Kings             74
# 686         Perth Wildcats         93  Sydney Kings             80
# 245   New Zealand Breakers         78  Sydney Kings             92
#
#            Player  PlayerNo    X     Y ShotType SubType  Result  Quarter  \
# 633    C. Prather        10  5.5  50.0      2pt    dunk       1        1
# 1743   C. Prather        12  5.5  50.0      2pt    dunk       1        2
# 1774     J. McKay         5  5.5  50.0      2pt    dunk       1        4
# 686      J. McKay         4  5.5  50.0      2pt    dunk       1        4
# 245   A. Mitchell        11  5.5  50.0      2pt    dunk       1        4
#
#                       Season League  W_L  3PM  distance  distance_m  \
# 633   2016-17 Regular Season    NBL    0    0       0.0         0.0
# 1743  2016-17 Regular Season    NBL    0    0       0.0         0.0
# 1774  2016-17 Regular Season    NBL    0    0       0.0         0.0
# 686   2016-17 Regular Season    NBL    0    0       0.0         0.0
# 245   2016-17 Regular Season    NBL    1    0       0.0         0.0
#
#             Court_Loc
# 633   Restricted_Area
# 1743  Restricted_Area
# 1774  Restricted_Area
# 686   Restricted_Area
# 245   Restricted_Area

# %%
kings.loc[kings['SubType']== 'three']
# Out:
#                       Team  teamScore      opponent  opponentScore  \
# 896        Illawarra Hawks         93  Sydney Kings             99
# 1398  New Zealand Breakers         92  Sydney Kings             74
# 1778        Perth Wildcats        101  Sydney Kings             74
# 938        Illawarra Hawks         93  Sydney Kings             99
# 645         Perth Wildcats         93  Sydney Kings             80
# 1766        Perth Wildcats        101  Sydney Kings             74
# 1744        Perth Wildcats        101  Sydney Kings             74
# 1735        Perth Wildcats        101  Sydney Kings             74
# 1754        Perth Wildcats        101  Sydney Kings             74
# 1750        Perth Wildcats        101  Sydney Kings             74
# 940        Illawarra Hawks         93  Sydney Kings             99
# 1137        Adelaide 36ers         79  Sydney Kings             80
# 1000        Cairns Taipans         78  Sydney Kings             86
# 1016        Cairns Taipans         78  Sydney Kings             86
# 765       Melbourne United         95  Sydney Kings             92
# 1611  New Zealand Breakers         57  Sydney Kings             84
# 1145        Adelaide 36ers         79  Sydney Kings             80
# 1173        Adelaide 36ers        103  Sydney Kings             96
# 994         Cairns Taipans         78  Sydney Kings             86
# 667         Perth Wildcats         93  Sydney Kings             80
# 1569      Brisbane Bullets         77  Sydney Kings             80
# 1575      Brisbane Bullets         77  Sydney Kings             80
# 918        Illawarra Hawks         93  Sydney Kings             99
# 1680      Melbourne United         89  Sydney Kings             76
# 631         Perth Wildcats         93  Sydney Kings             80
# 557       Brisbane Bullets         86  Sydney Kings             73
# 1406  New Zealand Breakers         92  Sydney Kings             74
# 439         Cairns Taipans         77  Sydney Kings             79
# 447         Cairns Taipans         77  Sydney Kings             79
# 396         Cairns Taipans         64  Sydney Kings             57
# ...                    ...        ...           ...            ...
# 587       Melbourne United         71  Sydney Kings             87
# 780       Melbourne United         95  Sydney Kings             92
# 359       Brisbane Bullets         78  Sydney Kings             87
# 589       Melbourne United         71  Sydney Kings             87
# 246   New Zealand Breakers         78  Sydney Kings             92
# 1412  New Zealand Breakers         92  Sydney Kings             74
# 36        Brisbane Bullets         77  Sydney Kings             73
# 147         Cairns Taipans         78  Sydney Kings             92
# 369       Brisbane Bullets         78  Sydney Kings             87
# 184         Cairns Taipans         78  Sydney Kings             92
# 770       Melbourne United         95  Sydney Kings             92
# 756       Melbourne United         95  Sydney Kings             92
# 1497        Adelaide 36ers         87  Sydney Kings             73
# 1068      Melbourne United         88  Sydney Kings             81
# 678         Perth Wildcats         93  Sydney Kings             80
# 1085      Melbourne United         88  Sydney Kings             81
# 182         Cairns Taipans         78  Sydney Kings             92
# 750       Melbourne United         95  Sydney Kings             92
# 814       Melbourne United         95  Sydney Kings             92
# 801       Melbourne United         95  Sydney Kings             92
# 768       Melbourne United         95  Sydney Kings             92
# 1303  New Zealand Breakers         80  Sydney Kings             85
# 1351        Perth Wildcats         80  Sydney Kings             74
# 1058      Melbourne United         88  Sydney Kings             81
# 810       Melbourne United         95  Sydney Kings             92
# 1087      Melbourne United         88  Sydney Kings             81
# 1047      Melbourne United         88  Sydney Kings             81
# 290        Illawarra Hawks         73  Sydney Kings             90
# 302        Illawarra Hawks         73  Sydney Kings             90
# 882         Adelaide 36ers         91  Sydney Kings             85
#
#                Player  PlayerNo       X       Y ShotType SubType  Result  \
# 896         M. Harris        10   9.472   7.143      3pt   three       0
# 1398       K. Dillard         8  21.129  15.646      3pt   three       0
# 1778         M. Bragg         9   4.189   4.762      3pt   three       0
# 938       T. Coenraad         9   4.918  95.918      3pt   three       0
# 645   D. Kernich-Drew         6   7.832  95.918      3pt   three       1
# 1766        D. Martin        17   5.647   3.741      3pt   three       0
# 1744        B. Cotton         1   5.282   3.741      3pt   three       1
# 1735        B. Cotton         1   5.100  96.259      3pt   three       0
# 1754       C. Prather        12   6.922   3.741      3pt   three       0
# 1750        D. Martin        17   4.007  96.259      3pt   three       0
# 940         O. Forman         3   3.825   3.741      3pt   three       1
# 1137          B. Teys         4   7.468   3.741      3pt   three       0
# 1000         T. Trice         1   7.650   3.741      3pt   three       0
# 1016         T. Trice         1  18.944  10.884      3pt   three       1
# 765         D. Barlow        14  23.133  82.993      3pt   three       1
# 1611   T. Abercrombie         4   5.100  96.599      3pt   three       0
# 1145       D. Johnson        10   5.100   3.401      3pt   three       0
# 1173       D. Johnson        10   8.561   3.741      3pt   three       1
# 994        C. Gliddon         2   8.561   3.741      3pt   three       1
# 667        J. Johnson         2   6.193   3.401      3pt   three       1
# 1569         S. Bruce         7   6.375  96.599      3pt   three       0
# 1575        M. Kenyon         5   4.554  96.599      3pt   three       1
# 918         R. Clarke         8   6.557  96.599      3pt   three       0
# 1680      C. Goulding        15   4.372  96.599      3pt   three       0
# 631          J. Kenny         5   6.740  96.599      3pt   three       0
# 557        D. Kickert         8   7.117   3.413      3pt   three       0
# 1406           S. Ili        12  11.111   4.422      3pt   three       0
# 439        C. Gliddon         2  19.854  88.435      3pt   three       1
# 447          D. Heuir         3   8.197  96.599      3pt   three       0
# 396          F. Edwin         9   8.379   3.401      3pt   three       0
# ...               ...       ...     ...     ...      ...     ...     ...
# 587       D. Andersen         7  30.601  20.068      3pt   three       0
# 780       C. Goulding        13  29.508  17.007      3pt   three       0
# 359          T. Craig         3  31.752  23.208      3pt   three       1
# 589          K. Adnam         4  33.151  71.429      3pt   three       1
# 246        C. Webster         4  31.934  76.451      3pt   three       0
# 1412        P. Carter        11  27.140  11.224      3pt   three       1
# 36          M. Kenyon        12  24.453   6.485      3pt   three       0
# 147       M. McCarron         4  31.934  77.133      3pt   three       1
# 369           J. Beal         1  32.299  23.891      3pt   three       0
# 184        C. Gliddon         2  29.927  16.724      3pt   three       0
# 770           C. Ware        10  29.690  15.986      3pt   three       1
# 756         O. Odigie         9  28.051  88.095      3pt   three       0
# 1497       D. Johnson        10  35.155  36.735      3pt   three       0
# 1068   T. Blanchfield         6  28.233  88.435      3pt   three       0
# 678       J. Wagstaff        11  36.248  50.680      3pt   three       1
# 1085          C. Ware        10  32.423  21.429      3pt   three       0
# 182       M. McCarron         4  33.577  25.597      3pt   three       1
# 750           C. Ware        10  30.601  15.986      3pt   three       0
# 814           C. Ware        10  36.430  55.102      3pt   three       1
# 801       C. Goulding        13  35.519  34.694      3pt   three       1
# 768           C. Ware        10  34.062  73.129      3pt   three       0
# 1303           S. Ili        15  29.508  12.925      3pt   three       1
# 1351  D. Kernich-Drew         7  35.519  67.347      3pt   three       0
# 1058          C. Ware        10  32.605  19.388      3pt   three       1
# 810           C. Ware        10  35.701  28.571      3pt   three       0
# 1087          C. Ware        10  30.601  11.565      3pt   three       0
# 1047      C. Goulding        13  35.883  23.810      3pt   three       1
# 290       T. Coenraad         9  37.409  26.280      3pt   three       0
# 302            N. Kay         6  37.409  79.863      3pt   three       0
# 882        D. Johnson        10  39.709  74.150      3pt   three       0
#
#       Quarter                  Season League  W_L  3PM   distance  distance_m  \
# 896         1  2016-17 Regular Season    NBL    1    0  43.040670    6.524044
# 1398        1  2016-17 Regular Season    NBL    0    0  37.742058    6.760537
# 1778        4  2016-17 Regular Season    NBL    0    0  45.256992    6.795622
# 938         3  2016-17 Regular Season    NBL    1    0  45.921688    6.889628
# 645         2  2016-17 Regular Season    NBL    0    1  45.977179    6.918581
# 1766        4  2016-17 Regular Season    NBL    0    0  46.259234    6.938972
# 1744        2  2016-17 Regular Season    NBL    0    1  46.259514    6.939118
# 1735        2  2016-17 Regular Season    NBL    0    0  46.260729    6.939754
# 1754        3  2016-17 Regular Season    NBL    0    0  46.280851    6.950264
# 1750        3  2016-17 Regular Season    NBL    0    0  46.283087    6.951431
# 940         4  2016-17 Regular Season    NBL    1    1  46.289315    6.954682
# 1137        4  2016-17 Regular Season    NBL    1    0  46.300843    6.960696
# 1000        3  2016-17 Regular Season    NBL    1    0  46.308936    6.964915
# 1016        4  2016-17 Regular Season    NBL    1    1  41.361849    6.971118
# 765         1  2016-17 Regular Season    NBL    0    1  37.409367    6.990597
# 1611        2  2016-17 Regular Season    NBL    1    0  46.600717    6.990747
# 1145        4  2016-17 Regular Season    NBL    1    0  46.600717    6.990747
# 1173        2  2016-17 Regular Season    NBL    0    1  46.360164    6.991582
# 994         3  2016-17 Regular Season    NBL    1    1  46.360164    6.991582
# 667         3  2016-17 Regular Season    NBL    0    1  46.604153    6.992543
# 1569        4  2016-17 Regular Season    NBL    1    0  46.607214    6.994142
# 1575        4  2016-17 Regular Season    NBL    1    1  46.608601    6.994867
# 918         2  2016-17 Regular Season    NBL    1    0  46.610986    6.996113
# 1680        2  2016-17 Regular Season    NBL    0    0  46.612650    6.996982
# 631         1  2016-17 Regular Season    NBL    0    0  46.615495    6.998468
# 557         4  2016-17 Regular Season    NBL    0    0  46.615054    7.002702
# 1406        1  2016-17 Regular Season    NBL    0    0  45.922080    7.014896
# 439         1  2016-17 Regular Season    NBL    1    1  41.027875    7.027904
# 447         1  2016-17 Regular Season    NBL    1    0  46.676982    7.030524
# 396         2  2016-17 Regular Season    NBL    0    0  46.687851    7.036180
# ...       ...                     ...    ...  ...  ...        ...         ...
# 587         2  2016-17 Regular Season    NBL    1    0  39.063856    8.339965
# 780         2  2016-17 Regular Season    NBL    0    0  40.803457    8.347492
# 359         4  2016-17 Regular Season    NBL    1    1  37.509716    8.377439
# 589         2  2016-17 Regular Season    NBL    1    1  34.982565    8.383015
# 246         4  2016-17 Regular Season    NBL    1    0  37.395344    8.397901
# 1412        2  2016-17 Regular Season    NBL    0    1  44.405718    8.399072
# 36          3  2016-17 Regular Season    NBL    0    0  47.463369    8.412345
# 147         1  2016-17 Regular Season    NBL    1    1  37.880814    8.446715
# 369         4  2016-17 Regular Season    NBL    1    0  37.414787    8.464255
# 184         4  2016-17 Regular Season    NBL    1    0  41.279178    8.467211
# 770         2  2016-17 Regular Season    NBL    0    1  41.738571    8.479839
# 756         1  2016-17 Regular Season    NBL    0    0  44.269364    8.516031
# 1497        3  2016-17 Regular Season    NBL    0    0  32.486601    8.538475
# 1068        3  2016-17 Regular Season    NBL    0    0  44.654658    8.588037
# 678         3  2016-17 Regular Season    NBL    0    1  30.755518    8.610044
# 1085        4  2016-17 Regular Season    NBL    0    0  39.257483    8.671498
# 182         4  2016-17 Regular Season    NBL    1    1  37.199789    8.671967
# 750         1  2016-17 Regular Season    NBL    0    0  42.273069    8.684938
# 814         4  2016-17 Regular Season    NBL    0    1  31.347971    8.694148
# 801         4  2016-17 Regular Season    NBL    0    1  33.695905    8.713241
# 768         2  2016-17 Regular Season    NBL    0    0  36.752394    8.717463
# 1303        2  2016-17 Regular Season    NBL    1    1  44.169443    8.724449
# 1351        1  2016-17 Regular Season    NBL    0    0  34.670719    8.798867
# 1058        3  2016-17 Regular Season    NBL    0    1  40.887352    8.870379
# 810         4  2016-17 Regular Season    NBL    0    0  37.031101    9.046586
# 1087        4  2016-17 Regular Season    NBL    0    0  45.905440    9.090370
# 1047        2  2016-17 Regular Season    NBL    0    1  40.112876    9.370499
# 290         3  2016-17 Regular Season    NBL    1    0  39.759561    9.616913
# 302         4  2016-17 Regular Season    NBL    1    0  43.703353    9.994555
# 882         4  2016-17 Regular Season    NBL    0    0  41.874553   10.240632
#
#              Court_Loc
# 896   Right_Corner_3pt
# 1398    Right_Wing_3pt
# 1778  Right_Corner_3pt
# 938    Left_Corner_3pt
# 645    Left_Corner_3pt
# 1766  Right_Corner_3pt
# 1744  Right_Corner_3pt
# 1735   Left_Corner_3pt
# 1754  Right_Corner_3pt
# 1750   Left_Corner_3pt
# 940   Right_Corner_3pt
# 1137  Right_Corner_3pt
# 1000  Right_Corner_3pt
# 1016    Right_Wing_3pt
# 765      Left_Wing_3pt
# 1611   Left_Corner_3pt
# 1145  Right_Corner_3pt
# 1173  Right_Corner_3pt
# 994   Right_Corner_3pt
# 667   Right_Corner_3pt
# 1569   Left_Corner_3pt
# 1575   Left_Corner_3pt
# 918    Left_Corner_3pt
# 1680   Left_Corner_3pt
# 631    Left_Corner_3pt
# 557   Right_Corner_3pt
# 1406    Right_Wing_3pt
# 439      Left_Wing_3pt
# 447    Left_Corner_3pt
# 396   Right_Corner_3pt
# ...                ...
# 587     Right_Wing_3pt
# 780     Right_Wing_3pt
# 359     Right_Wing_3pt
# 589      Left_Wing_3pt
# 246      Left_Wing_3pt
# 1412    Right_Wing_3pt
# 36      Right_Wing_3pt
# 147      Left_Wing_3pt
# 369     Right_Wing_3pt
# 184     Right_Wing_3pt
# 770     Right_Wing_3pt
# 756      Left_Wing_3pt
# 1497    Top_of_Key_3pt
# 1068     Left_Wing_3pt
# 678     Top_of_Key_3pt
# 1085    Right_Wing_3pt
# 182     Right_Wing_3pt
# 750     Right_Wing_3pt
# 814     Top_of_Key_3pt
# 801     Top_of_Key_3pt
# 768      Left_Wing_3pt
# 1303    Right_Wing_3pt
# 1351     Left_Wing_3pt
# 1058    Right_Wing_3pt
# 810     Right_Wing_3pt
# 1087    Right_Wing_3pt
# 1047    Right_Wing_3pt
# 290     Right_Wing_3pt
# 302      Left_Wing_3pt
# 882      Left_Wing_3pt
#
# [567 rows x 19 columns]

# %% [markdown]
# ### Discussion:
# I want to check to make sure my distances were calculated correctly.  When 2pts have distances from the hoop that are farter than three pointers, I got concerned.  I will plot based on ShotType 2pt, 3pt on the court diagram just to make sure.

# %%
threes = kings.loc[kings['ShotType']== '3pt'].copy()
twos = kings.loc[kings['ShotType']== '2pt'].copy()

# %%
from matplotlib.patches import Circle, Rectangle, Arc
hoop = Circle((50, 5.5), radius=1.5, linewidth=2, color='black', fill=False)
backboard = Rectangle((45, 4), 10, 0, linewidth=4, color='black')
three_a = Rectangle((6.5, 4), 0, 9.5, linewidth=2, color='black')
three_b = Rectangle((93.5, 4), 0, 9.5, linewidth=2, color='black')
three_arc = Arc((50, 12.5), 87, 34, theta1=2, theta2=178, linewidth=2, color='black')

plt.figure(figsize=(12,8))
ax = plt.gca()
ax.add_patch(hoop)
ax.add_patch(backboard)
ax.add_patch(three_a)
ax.add_patch(three_b)
ax.add_patch(three_arc)
plt.scatter(twos.Y, twos.X, facecolors = 'purple', alpha = .5)
plt.show()

# %%
hoop = Circle((50, 5.5), radius=1.5, linewidth=2, color='black', fill=False)
backboard = Rectangle((45, 4), 10, 0, linewidth=4, color='black')
three_a = Rectangle((6.5, 4), 0, 9.5, linewidth=2, color='black')
three_b = Rectangle((93.5, 4), 0, 9.5, linewidth=2, color='black')
three_arc = Arc((50, 12.5), 87, 34, theta1=2, theta2=178, linewidth=2, color='black')

plt.figure(figsize=(12, 12))
ax = plt.gca()
ax.add_patch(hoop)
ax.add_patch(backboard)
ax.add_patch(three_a)
ax.add_patch(three_b)
ax.add_patch(three_arc)
plt.scatter(threes.Y, threes.X, facecolors = 'purple', alpha = .5)
plt.show()

# %%
#Just testing this hexbin functionality through matplotlib
plt.figure(figsize=(10, 8))
hb_shot = plt.hexbin(kings.Y, kings.X, gridsize=8, color ='m')
plt.show()

# %% [markdown]
# #### Discussion:
# Create X's based on ShotType, distance, Team, and new created column Bins. There are a couple of shots that are off but are close enough that we will keep them in the categories.  Until I have a solid way of accurately mapping the court to scale, I don't want to make changes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.misc import imread
import matplotlib.cbook as cbook

plt.figure(figsize=(12,12))
ax = plt.gca()
datafile = cbook.get_sample_data('/Users/ericnesi/Desktop/capstone_eric/images/NBL_Court.jpg')
img = imread(datafile)
plt.imshow(img, zorder=0, extent=[0, 100, 0, 50])
plt.scatter(kings.Y, kings.X, facecolors = 'purple', alpha = .5)
plt.show()

# %%
#Originally, I binned as following, but I refined this after I was able to calculate the correct distances from the hoop.
#As such, I removed the creation of these bins

hoop = Circle((50, 5.5), radius=1.5, linewidth=2, color='black', fill=False)
backboard = Rectangle((45, 4), 10, 0, linewidth=4, color='black')
three_a = Rectangle((6.5, 4), 0, 9.5, linewidth=2, color='black')
three_b = Rectangle((93.5, 4), 0, 9.5, linewidth=2, color='black')
three_arc = Arc((50, 12.5), 87, 34, theta1=2, theta2=178, linewidth=2, color='black')



plt.figure(figsize=(12,8))
ax = plt.gca()
ax.add_patch(hoop)
ax.add_patch(backboard)
ax.add_patch(three_a)
ax.add_patch(three_b)
ax.add_patch(three_arc)
plt.axvline(x=0)
plt.axvline(x=20)
plt.axvline(x=40)
plt.axvline(x=60)
plt.axvline(x=80)
plt.axvline(x=100)
plt.axhline(y=15)
plt.axhline(y=30)
plt.axhline(y=45)
plt.scatter(kings.Y, kings.X, facecolors = 'purple', alpha = .5)
plt.show()

# %%
kings.sort_values(['distance_m'], inplace=True, ascending=False) 
kings.head()
# Out:
#                   Team  teamScore      opponent  opponentScore       Player  \
# 882     Adelaide 36ers         91  Sydney Kings             85   D. Johnson
# 302    Illawarra Hawks         73  Sydney Kings             90       N. Kay
# 290    Illawarra Hawks         73  Sydney Kings             90  T. Coenraad
# 1047  Melbourne United         88  Sydney Kings             81  C. Goulding
# 1087  Melbourne United         88  Sydney Kings             81      C. Ware
#
#       PlayerNo       X       Y ShotType SubType  Result  Quarter  \
# 882         10  39.709  74.150      3pt   three       0        4
# 302          6  37.409  79.863      3pt   three       0        4
# 290          9  37.409  26.280      3pt   three       0        3
# 1047        13  35.883  23.810      3pt   three       1        2
# 1087        10  30.601  11.565      3pt   three       0        4
#
#                       Season League  W_L  3PM   distance  distance_m  \
# 882   2016-17 Regular Season    NBL    0    0  41.874553   10.240632
# 302   2016-17 Regular Season    NBL    1    0  43.703353    9.994555
# 290   2016-17 Regular Season    NBL    1    0  39.759561    9.616913
# 1047  2016-17 Regular Season    NBL    0    1  40.112876    9.370499
# 1087  2016-17 Regular Season    NBL    0    0  45.905440    9.090370
#
#            Court_Loc
# 882    Left_Wing_3pt
# 302    Left_Wing_3pt
# 290   Right_Wing_3pt
# 1047  Right_Wing_3pt
# 1087  Right_Wing_3pt

# %%
#Set my X_features and append to dataframe
X_features = kings[['Court_Loc','Quarter']]
X_features = pd.concat([pd.get_dummies(X_features[col]) for col in X_features], axis=1)
X_features['distance_m'] = kings['distance_m']

# %%
X_features.head()
# Out:
#       In_the_Paint  Left_Corner  Left_Corner_3pt  Left_Wing  Left_Wing_3pt  \
# 882              0            0                0          0              1
# 302              0            0                0          0              1
# 290              0            0                0          0              0
# 1047             0            0                0          0              0
# 1087             0            0                0          0              0
#
#       Restricted_Area  Right_Corner  Right_Corner_3pt  Right_Wing  \
# 882                 0             0                 0           0
# 302                 0             0                 0           0
# 290                 0             0                 0           0
# 1047                0             0                 0           0
# 1087                0             0                 0           0
#
#       Right_Wing_3pt  Top_of_Key  Top_of_Key_3pt  1  2  3  4  distance_m
# 882                0           0               0  0  0  0  1   10.240632
# 302                0           0               0  0  0  0  1    9.994555
# 290                1           0               0  0  0  1  0    9.616913
# 1047               1           0               0  0  1  0  0    9.370499
# 1087               1           0               0  0  0  0  1    9.090370

# %% [markdown]
# #### **Random Forest:**

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

Xs = ss.fit_transform(X_features)

Y = kings['Result']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

Xtrain, Xtest, ytrain, ytest = train_test_split(Xs, Y, test_size=0.33)

dtc = DecisionTreeClassifier(max_depth=None, max_features='auto')
dtc.fit(Xtrain, ytrain)
print ('dtc acc:', dtc.score(Xtest, ytest))

rf = RandomForestClassifier(n_estimators=1000, max_depth=None, max_features='auto')
rf.fit(Xtrain, ytrain)
yhat = rf.predict(Xtest)
print ('rf acc:', accuracy_score(ytest, yhat))
# Out:
# dtc acc: 0.542517006803
# rf acc: 0.544217687075

# %% [markdown]
# At this point, I realized predicting whether or not a shot is going to be made is potentially not a great option, but while I am doing it, I decided to try logistic regression to see if I could improve accuracy.  Not a great prediction score by RF/DTC.

# %% [markdown]
# #### **Logistic Regression:**

# %%
# Set parameters for gridsearching
# Taken from 6.3.3. and 6.3.4

gs_params = {
    'penalty':['l1','l2'],
    'solver':['liblinear'],
    'C':np.logspace(-5,0,100)
}

lr_gridsearch = GridSearchCV(LogisticRegression(), gs_params, cv=5, verbose=1)
print (lr_gridsearch)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'solver': ['liblinear'], 'C': array([  1.00000e-05,   1.12332e-05, ...,   8.90215e-01,   1.00000e+00])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=1)

# %%
# TTS our data.
# We will have a holdout set to test on at the end.
X_train, X_test, y_train, y_test = train_test_split(Xs, Y, test_size=0.3, random_state=12)

# %%
lr_gridsearch.fit(X_train, y_train)

print (lr_gridsearch.best_score_)
print (lr_gridsearch.best_params_)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# 0.626003210273
# {'C': 0.0095454845666183372, 'penalty': 'l1', 'solver': 'liblinear'}
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    4.6s finished

# %%
bestfit = {'C': 0.0095454845666183372, 'penalty':'l1', 'solver': 'liblinear'}

logreg = LogisticRegression(C=0.0095454845666183372, penalty='l1', solver='liblinear')

logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.009545484566618337, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
Y_pred = logreg.predict(X_test)

# stores confusion matrix for Y Test and Y Pred  
conmat = confusion_matrix(y_test, Y_pred, labels=logreg.classes_)
# converts np.matrix format matrix to a dataframe and adds index and column names
conmat = pd.DataFrame(conmat, columns=logreg.classes_, index=logreg.classes_)

print ('best params for Result:')
print (conmat)
# Out:
# best params for Result:
#      0   1
# 0  248  32
# 1  173  82

# %%
print(classification_report(y_test, Y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.59      0.89      0.71       280
#           1       0.72      0.32      0.44       255
#
# avg / total       0.65      0.62      0.58       535

# %%
best_lr = lr_gridsearch.best_estimator_

print (best_lr.score(Xs, Y))
# Out:
# 0.623245367771

# %%
coef_df = pd.DataFrame({
        'coef':best_lr.coef_[0],
        'feature':X_features.columns
    })


coef_df['abs_coef'] = np.abs(coef_df.coef)

# sort by absolute value of coefficient (magnitude)
coef_df.sort_values('abs_coef', ascending=False, inplace=True)

coef_df.head(12)
# Out:
#        coef           feature  abs_coef
# 5   0.15422   Restricted_Area   0.15422
# 0   0.00000      In_the_Paint   0.00000
# 9   0.00000    Right_Wing_3pt   0.00000
# 15  0.00000                 4   0.00000
# 14  0.00000                 3   0.00000
# 13  0.00000                 2   0.00000
# 12  0.00000                 1   0.00000
# 11  0.00000    Top_of_Key_3pt   0.00000
# 10  0.00000        Top_of_Key   0.00000
# 8   0.00000        Right_Wing   0.00000
# 1   0.00000       Left_Corner   0.00000
# 7   0.00000  Right_Corner_3pt   0.00000

# %% [markdown]
# #### Discussion:
# This is not surprising that the closer to the basket you are the more likely you are to make the shot. That said, the prediction score isn't great.  Furthermore, it is really not what I am trying to accomplish with the project.  I will explain more in Summary.

# %%
print(kings.shape)
print(kings.Court_Loc.unique())
# Out:
# (1781, 19)
# ['Left_Wing_3pt' 'Right_Wing_3pt' 'Top_of_Key_3pt' 'Left_Corner_3pt'
#  'Right_Corner_3pt' 'Right_Wing' 'Top_of_Key' 'Left_Wing' 'Right_Corner'
#  'Left_Corner' 'In_the_Paint' 'Restricted_Area']

# %%
print(np.sum(kings.Court_Loc =="Restricted_Area")/1781)
print(np.sum(kings.Court_Loc =='Left_Wing_3pt')/1781)
print(np.sum(kings.Court_Loc =='Right_Wing_3pt')/1781)
print(np.sum(kings.Court_Loc =='Top_of_Key_3pt')/1781)
print(np.sum(kings.Court_Loc =='Left_Corner_3pt')/1781)
print(np.sum(kings.Court_Loc =='Right_Corner_3pt')/1781)
print(np.sum(kings.Court_Loc =='Top_of_Key')/1781)
print(np.sum(kings.Court_Loc =='Left_Wing')/1781)
print(np.sum(kings.Court_Loc =='Right_Corner')/1781)
print(np.sum(kings.Court_Loc =='Left_Corner')/1781)
print(np.sum(kings.Court_Loc =='In_the_Paint')/1781)
# Out:
# 0.212801796743
# 0.111173498035
# 0.115665356541
# 0.0606400898372
# 0.0151600224593
# 0.0157215047726
# 0.0224592925323
# 0.0359348680517
# 0.0230207748456
# 0.0252667040988
# 0.329028635598

# %% [markdown]
# ## End Part3 Notebook
